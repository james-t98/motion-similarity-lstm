# %%
# !pip install -r "/content/drive/MyDrive/sdc_msc_data_analytics_project/requirements.txt"

# %%
# !python "/content/drive/MyDrive/sdc_msc_data_analytics_project/cleanup.py" --mode "all"
# Out:
# 🧼 Cleared: /content/drive/MyDrive/sdc_msc_data_analytics_project/export_data
# 🧼 Cleared: /content/drive/MyDrive/sdc_msc_data_analytics_project/plots
# 🧼 Cleared: /content/drive/MyDrive/sdc_msc_data_analytics_project/data/video/output
# 🧼 Cleared: /content/drive/MyDrive/sdc_msc_data_analytics_project/logs/inference
# 🧼 Deleted model: /content/drive/MyDrive/sdc_msc_data_analytics_project/models/squat_cosine_model.h5

# %%
# !python "/content/drive/MyDrive/sdc_msc_data_analytics_project/run_all.py" \
  --category "physio" \
  --exercise "squat" \
  --similarity_method "cosine" \
  --model_name "squat_cosine_model"

# %%
# !python "/content/drive/MyDrive/sdc_msc_data_analytics_project/embedding_visualization.py" \
  --model_path "/content/drive/MyDrive/sdc_msc_data_analytics_project/models/squat_cosine_model.h5" \
  --data_root "export_data" \
  --category "physio" \
  --exercise "squat"

# %%
# !python "/content/drive/MyDrive/sdc_msc_data_analytics_project/generate_summary_report.py"
